# %%
import pandas._testing as tm
import pandas as pd
import numpy as np
#https://en.wikipedia.org/wiki/Wide_and_narrow_data
#https://pandas.pydata.org/pandas-docs/stable/user_guide/reshaping.html

# %% [markdown]
# # Tall Table (Stacked data)
# # Wide Table (Unstacked data)

# %%
tm.makeTimeDataFrame()
# Out:
#                    A         B         C         D
# 2000-01-03 -0.299000 -0.500045  0.392584 -1.675921
# 2000-01-04  0.376418 -0.121663 -2.194653  1.081968
# 2000-01-05 -0.229896  0.985452 -0.555044  0.754344

# %%
tm.N = 3

def unpivot(frame):
    N, K = frame.shape
    data = {
        "value": frame.to_numpy().ravel("F"),
        "variable": np.asarray(frame.columns).repeat(N),
        "date": np.tile(np.asarray(frame.index), K)
    }
    return pd.DataFrame(data, columns=["date", "variable", "value"])

df = unpivot(tm.makeTimeDataFrame())

# %%
df
# Out:
#          date variable     value
# 0  2000-01-03        A -0.477556
# 1  2000-01-04        A -1.826072
# 2  2000-01-05        A -0.858497
# 3  2000-01-03        B -0.585475
# 4  2000-01-04        B -0.262681
# 5  2000-01-05        B  1.352586
# 6  2000-01-03        C -2.379398
# 7  2000-01-04        C -0.540838
# 8  2000-01-05        C  1.283320
# 9  2000-01-03        D  0.450734
# 10 2000-01-04        D -1.075851
# 11 2000-01-05        D -1.441012

# %%
df[df["variable"] == "A"]
# Out:
#         date variable     value
# 0 2000-01-03        A -0.477556
# 1 2000-01-04        A -1.826072
# 2 2000-01-05        A -0.858497

# %% [markdown]
# ### 如果要做時間序列分析的話，我們會希望x軸是時間,y軸值,所以我們會想把這個tall table轉換成wide table

# %%
df.pivot(index="date", columns="variable", values="value")
# Out:
# variable           A         B         C         D
# date
# 2000-01-03 -0.477556 -0.585475 -2.379398  0.450734
# 2000-01-04 -1.826072 -0.262681 -0.540838 -1.075851
# 2000-01-05 -0.858497  1.352586  1.283320 -1.441012

# %%
df["value2"] = df["value"] * 2

# %%
df
# Out:
#          date variable     value    value2
# 0  2000-01-03        A -0.477556 -0.955112
# 1  2000-01-04        A -1.826072 -3.652144
# 2  2000-01-05        A -0.858497 -1.716993
# 3  2000-01-03        B -0.585475 -1.170951
# 4  2000-01-04        B -0.262681 -0.525362
# 5  2000-01-05        B  1.352586  2.705173
# 6  2000-01-03        C -2.379398 -4.758796
# 7  2000-01-04        C -0.540838 -1.081676
# 8  2000-01-05        C  1.283320  2.566641
# 9  2000-01-03        D  0.450734  0.901467
# 10 2000-01-04        D -1.075851 -2.151701
# 11 2000-01-05        D -1.441012 -2.882024

# %%
pivoted = df.pivot(index="date", columns="variable")

# %%
pivoted
# Out:
#                value                                  value2            \
# variable           A         B         C         D         A         B
# date
# 2000-01-03 -0.477556 -0.585475 -2.379398  0.450734 -0.955112 -1.170951
# 2000-01-04 -1.826072 -0.262681 -0.540838 -1.075851 -3.652144 -0.525362
# 2000-01-05 -0.858497  1.352586  1.283320 -1.441012 -1.716993  2.705173
#
#
# variable           C         D
# date
# 2000-01-03 -4.758796  0.901467
# 2000-01-04 -1.081676 -2.151701
# 2000-01-05  2.566641 -2.882024

# %%
pivoted2 = df.pivot_table(index="date", columns="variable")

# %%
pivoted2
# Out:
#                value                                  value2            \
# variable           A         B         C         D         A         B
# date
# 2000-01-03 -0.477556 -0.585475 -2.379398  0.450734 -0.955112 -1.170951
# 2000-01-04 -1.826072 -0.262681 -0.540838 -1.075851 -3.652144 -0.525362
# 2000-01-05 -0.858497  1.352586  1.283320 -1.441012 -1.716993  2.705173
#
#
# variable           C         D
# date
# 2000-01-03 -4.758796  0.901467
# 2000-01-04 -1.081676 -2.151701
# 2000-01-05  2.566641 -2.882024

# %% [markdown]
# # MultiIndex stack and unstack

# %%
tuples = list(
    zip(*[
        [
        "bar","bar","baz","baz",
        "foo","foo","qux","qux"
        ],[
        "one", "two", "one", "two",
        "one", "two", "one", "two"
        ]
    ])
)

# %%
tuples
# Out:
# [('bar', 'one'),
#  ('bar', 'two'),
#  ('baz', 'one'),
#  ('baz', 'two'),
#  ('foo', 'one'),
#  ('foo', 'two'),
#  ('qux', 'one'),
#  ('qux', 'two')]

# %%
index = pd.MultiIndex.from_tuples(tuples, names=['first', 'second'])

# %%
df = pd.DataFrame(np.random.randn(8, 2), index=index, columns=['A', 'B'])

# %%
df
# Out:
#                      A         B
# first second
# bar   one     1.065098 -0.656297
#       two    -0.949864  0.496623
# baz   one    -0.805114 -1.770460
#       two    -0.214755  0.194256
# foo   one     0.281298  0.440289
#       two    -0.608542  0.268555
# qux   one    -0.424610 -0.740120
#       two    -1.578151 -1.138032

# %%
df2 = df[:4]

# %%
df2
# Out:
#                      A         B
# first second
# bar   one     1.065098 -0.656297
#       two    -0.949864  0.496623
# baz   one    -0.805114 -1.770460
#       two    -0.214755  0.194256

# %%
stacked = df2.stack()

# %%
stacked
# Out:
# first  second
# bar    one     A    1.065098
#                B   -0.656297
#        two     A   -0.949864
#                B    0.496623
# baz    one     A   -0.805114
#                B   -1.770460
#        two     A   -0.214755
#                B    0.194256
# dtype: float64

# %%
stacked.unstack()
# Out:
#                      A         B
# first second
# bar   one     1.065098 -0.656297
#       two    -0.949864  0.496623
# baz   one    -0.805114 -1.770460
#       two    -0.214755  0.194256

# %%
stacked.unstack(1)
# Out:
# second        one       two
# first
# bar   A  1.065098 -0.949864
#       B -0.656297  0.496623
# baz   A -0.805114 -0.214755
#       B -1.770460  0.194256

# %%
stacked.unstack(0)
# Out:
# first          bar       baz
# second
# one    A  1.065098 -0.805114
#        B -0.656297 -1.770460
# two    A -0.949864 -0.214755
#        B  0.496623  0.194256

# %%
index = pd.MultiIndex.from_product([[2, 1], ['a', 'b']])

# %%
df = pd.DataFrame(np.random.randn(4), index=index, columns=['A'])

# %%
df
# Out:
#             A
# 2 a -0.829279
#   b -0.274155
# 1 a -0.659968
#   b  2.006904

# %%
df.unstack().stack()
# Out:
#             A
# 1 a -0.659968
#   b  2.006904
# 2 a -0.829279
#   b -0.274155

# %%
df
# Out:
#             A
# 2 a -0.829279
#   b -0.274155
# 1 a -0.659968
#   b  2.006904

# %%
df.sort_index()
# Out:
#             A
# 1 a -0.659968
#   b  2.006904
# 2 a -0.829279
#   b -0.274155

# %%
all(df.unstack().stack() == df.sort_index())
# Out:
# True
